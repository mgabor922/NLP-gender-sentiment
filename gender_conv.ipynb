# %%
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation , Embedding , Flatten, Dropout, Convolution1D
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from keras.preprocessing import sequence
from keras.optimizers import Adam
import re
from keras.optimizers import SGD

#from keras.callbacks import TensorBoard
# males -> 1
# females -> 0

#read processed data
df_processed = pd.read_json("out2.json")
print("df head: " + str(df_processed.head()))

values_processed = df_processed.values
docs_padded_string = values_processed[:,2]
# calculate max_length based on the first entry of the 'post' column's encoded string (it conteins the encoded ints
# separated by ','-s so it will have to be split and converted back to int before use.)
max_length = len(docs_padded_string[0].split(','))
print("max_length: " + str(max_length))
padded_docs = np.zeros((len(docs_padded_string),max_length))
# convert the string to a list of ints by splitting them along ',' characters:
for i in range(len(docs_padded_string)):
    padded_docs[i] = [int(x) for x in docs_padded_string[i].split(",")]
    
#print("padded docs string: " + str(docs_padded_string[0]))
#print("padded docs: " + str(padded_docs[0]))
gender_list = values_processed[: , 1]
# check finalized word_dict:


# get valid/test/train split
valid_split = 0.2
test_split = 0.1
nb_samples = values_processed.shape[0]


X_train = padded_docs[0:int(nb_samples*(1-valid_split-test_split))]
Y_train = gender_list[0:int(nb_samples*(1-valid_split-test_split))]
X_valid = padded_docs[int(nb_samples*(1-valid_split-test_split)):int(nb_samples*(1-test_split))]
Y_valid = gender_list[int(nb_samples*(1-valid_split-test_split)):int(nb_samples*(1-test_split))]
X_test  = padded_docs[int(nb_samples*(1-test_split)):]
Y_test  = gender_list[int(nb_samples*(1-test_split)):]

# check shapes
print("X_train shape: " + str(X_train.shape))
print("Y_train shape: " + str(Y_train.shape))
print("X_valid shape: " + str(X_valid.shape))
print("Y_valid shape: " + str(Y_valid.shape))# define the model

vocab_size=len(padded_docs)


patience=20
early_stopping=EarlyStopping(patience=patience, verbose=1)
checkpointer=ModelCheckpoint(filepath='weights.hdf5', save_best_only=True, verbose=1)

model = Sequential()
model.add(Embedding(vocab_size, 64, input_length=max_length))

# Convolutional model (3x conv, flatten, 2x dense)
model.add(Convolution1D(256, 5, padding='same'))
model.add(Convolution1D(128, 5, padding='same'))
model.add(Convolution1D(64, 5, padding='same'))
model.add(Convolution1D(32, 5, padding='same'))
model.add(Convolution1D(16, 5, padding='same'))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(180, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

sgd = SGD(lr=1e-3, decay=1e-6, momentum=0.8, nesterov=True)
# compile the model
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
# summarize the model
print(model.summary())
print("X_test shape: " + str(X_test.shape))
print("Y_test shape: " + str(Y_test.shape))

model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose = 1, validation_data=(X_valid,Y_valid), \
          shuffle=True, callbacks=[checkpointer, early_stopping])

# Evaluation on the test set
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# df head:       age  gender                                               post
# 0      27       1  46408,46022,46703,11417,43813,49750,5081,20544...
# 1      25       1  13387,42001,39064,25330,28879,29212,25249,9543...
# 10     37       0  43492,18424,18424,18424,18424,32566,4029,5244,...
# 100    27       1  37946,45632,45632,20041,17489,12804,35990,4503...
# 1000   26       1  34086,43188,31677,5081,28821,31677,7087,24819,...
# max_length: 500
# X_train shape: (35000, 500)
# Y_train shape: (35000,)
# X_valid shape: (10000, 500)
# Y_valid shape: (10000,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 500, 64)           3200000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 500, 256)          82176
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 128)          163968
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 500, 64)           41024
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 500, 32)           10272
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 500, 16)           2576
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8000)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 180)               1440180
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 180)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 181
# =================================================================
# Total params: 4,940,377
# Trainable params: 4,940,377
# Non-trainable params: 0
# _________________________________________________________________
# None
# X_test shape: (5000, 500)
# Y_test shape: (5000,)
# Train on 35000 samples, validate on 10000 samples
# Epoch 1/100
# 35000/35000 [==============================] - 45s 1ms/step - loss: 0.6933 - acc: 0.5096 - val_loss: 0.6918 - val_acc: 0.5289
#
# Epoch 00001: val_loss improved from inf to 0.69179, saving model to weights.hdf5
# Epoch 2/100
# 35000/35000 [==============================] - 29s 818us/step - loss: 0.6925 - acc: 0.5179 - val_loss: 0.6913 - val_acc: 0.5221
#
# Epoch 00002: val_loss improved from 0.69179 to 0.69127, saving model to weights.hdf5
# Epoch 3/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6922 - acc: 0.5199 - val_loss: 0.6901 - val_acc: 0.5362
#
# Epoch 00003: val_loss improved from 0.69127 to 0.69013, saving model to weights.hdf5
# Epoch 4/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6917 - acc: 0.5249 - val_loss: 0.6903 - val_acc: 0.5337
#
# Epoch 00004: val_loss did not improve from 0.69013
# Epoch 5/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6913 - acc: 0.5275 - val_loss: 0.6905 - val_acc: 0.5395
#
# Epoch 00005: val_loss did not improve from 0.69013
# Epoch 6/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6910 - acc: 0.5310 - val_loss: 0.6900 - val_acc: 0.5381
#
# Epoch 00006: val_loss improved from 0.69013 to 0.69000, saving model to weights.hdf5
# Epoch 7/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6905 - acc: 0.5326 - val_loss: 0.6890 - val_acc: 0.5452
#
# Epoch 00007: val_loss improved from 0.69000 to 0.68895, saving model to weights.hdf5
# Epoch 8/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6894 - acc: 0.5379 - val_loss: 0.6891 - val_acc: 0.5328
#
# Epoch 00008: val_loss did not improve from 0.68895
# Epoch 9/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6891 - acc: 0.5414 - val_loss: 0.6868 - val_acc: 0.5390
#
# Epoch 00009: val_loss improved from 0.68895 to 0.68683, saving model to weights.hdf5
# Epoch 10/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6869 - acc: 0.5479 - val_loss: 0.6835 - val_acc: 0.5515
#
# Epoch 00010: val_loss improved from 0.68683 to 0.68345, saving model to weights.hdf5
# Epoch 11/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6846 - acc: 0.5598 - val_loss: 0.6811 - val_acc: 0.5688
#
# Epoch 00011: val_loss improved from 0.68345 to 0.68113, saving model to weights.hdf5
# Epoch 12/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6824 - acc: 0.5644 - val_loss: 0.6775 - val_acc: 0.5783
#
# Epoch 00012: val_loss improved from 0.68113 to 0.67747, saving model to weights.hdf5
# Epoch 13/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6798 - acc: 0.5720 - val_loss: 0.6769 - val_acc: 0.5778
#
# Epoch 00013: val_loss improved from 0.67747 to 0.67690, saving model to weights.hdf5
# Epoch 14/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6782 - acc: 0.5747 - val_loss: 0.6728 - val_acc: 0.5922
#
# Epoch 00014: val_loss improved from 0.67690 to 0.67283, saving model to weights.hdf5
# Epoch 15/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6757 - acc: 0.5817 - val_loss: 0.6832 - val_acc: 0.5504
#
# Epoch 00015: val_loss did not improve from 0.67283
# Epoch 16/100
# 35000/35000 [==============================] - 29s 824us/step - loss: 0.6743 - acc: 0.5822 - val_loss: 0.6836 - val_acc: 0.5521
#
# Epoch 00016: val_loss did not improve from 0.67283
# Epoch 17/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6712 - acc: 0.5886 - val_loss: 0.6677 - val_acc: 0.5955
#
# Epoch 00017: val_loss improved from 0.67283 to 0.66774, saving model to weights.hdf5
# Epoch 18/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6709 - acc: 0.5883 - val_loss: 0.6776 - val_acc: 0.5732
#
# Epoch 00018: val_loss did not improve from 0.66774
# Epoch 19/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6683 - acc: 0.5922 - val_loss: 0.6649 - val_acc: 0.6000
#
# Epoch 00019: val_loss improved from 0.66774 to 0.66492, saving model to weights.hdf5
# Epoch 20/100
# 35000/35000 [==============================] - 29s 819us/step - loss: 0.6661 - acc: 0.5985 - val_loss: 0.6598 - val_acc: 0.6137
#
# Epoch 00020: val_loss improved from 0.66492 to 0.65977, saving model to weights.hdf5
# Epoch 21/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6644 - acc: 0.6007 - val_loss: 0.6615 - val_acc: 0.6034
#
# Epoch 00021: val_loss did not improve from 0.65977
# Epoch 22/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6624 - acc: 0.6021 - val_loss: 0.6588 - val_acc: 0.6111
#
# Epoch 00022: val_loss improved from 0.65977 to 0.65884, saving model to weights.hdf5
# Epoch 23/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6600 - acc: 0.6042 - val_loss: 0.6540 - val_acc: 0.6133
#
# Epoch 00023: val_loss improved from 0.65884 to 0.65400, saving model to weights.hdf5
# Epoch 24/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6585 - acc: 0.6059 - val_loss: 0.6560 - val_acc: 0.6093
#
# Epoch 00024: val_loss did not improve from 0.65400
# Epoch 25/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6561 - acc: 0.6113 - val_loss: 0.6496 - val_acc: 0.6251
#
# Epoch 00025: val_loss improved from 0.65400 to 0.64958, saving model to weights.hdf5
# Epoch 26/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6544 - acc: 0.6138 - val_loss: 0.6478 - val_acc: 0.6200
#
# Epoch 00026: val_loss improved from 0.64958 to 0.64780, saving model to weights.hdf5
# Epoch 27/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6519 - acc: 0.6145 - val_loss: 0.6542 - val_acc: 0.6137
#
# Epoch 00027: val_loss did not improve from 0.64780
# Epoch 28/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6506 - acc: 0.6186 - val_loss: 0.6575 - val_acc: 0.6101
#
# Epoch 00028: val_loss did not improve from 0.64780
# Epoch 29/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6471 - acc: 0.6237 - val_loss: 0.6463 - val_acc: 0.6270
#
# Epoch 00029: val_loss improved from 0.64780 to 0.64627, saving model to weights.hdf5
# Epoch 30/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6463 - acc: 0.6233 - val_loss: 0.6409 - val_acc: 0.6319
#
# Epoch 00030: val_loss improved from 0.64627 to 0.64090, saving model to weights.hdf5
# Epoch 31/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6439 - acc: 0.6266 - val_loss: 0.6417 - val_acc: 0.6310
#
# Epoch 00031: val_loss did not improve from 0.64090
# Epoch 32/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6416 - acc: 0.6295 - val_loss: 0.6480 - val_acc: 0.6207
#
# Epoch 00032: val_loss did not improve from 0.64090
# Epoch 33/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6397 - acc: 0.6346 - val_loss: 0.6386 - val_acc: 0.6323
#
# Epoch 00033: val_loss improved from 0.64090 to 0.63863, saving model to weights.hdf5
# Epoch 34/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6364 - acc: 0.6392 - val_loss: 0.6353 - val_acc: 0.6386
#
# Epoch 00034: val_loss improved from 0.63863 to 0.63528, saving model to weights.hdf5
# Epoch 35/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6367 - acc: 0.6376 - val_loss: 0.6348 - val_acc: 0.6394
#
# Epoch 00035: val_loss improved from 0.63528 to 0.63477, saving model to weights.hdf5
# Epoch 36/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6326 - acc: 0.6420 - val_loss: 0.6366 - val_acc: 0.6340
#
# Epoch 00036: val_loss did not improve from 0.63477
# Epoch 37/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6312 - acc: 0.6461 - val_loss: 0.6433 - val_acc: 0.6264
#
# Epoch 00037: val_loss did not improve from 0.63477
# Epoch 38/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6297 - acc: 0.6473 - val_loss: 0.6356 - val_acc: 0.6358
#
# Epoch 00038: val_loss did not improve from 0.63477
# Epoch 39/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6267 - acc: 0.6486 - val_loss: 0.6430 - val_acc: 0.6296
#
# Epoch 00039: val_loss did not improve from 0.63477
# Epoch 40/100
# 35000/35000 [==============================] - 29s 824us/step - loss: 0.6254 - acc: 0.6492 - val_loss: 0.6641 - val_acc: 0.6148
#
# Epoch 00040: val_loss did not improve from 0.63477
# Epoch 41/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6243 - acc: 0.6524 - val_loss: 0.6312 - val_acc: 0.6414
#
# Epoch 00041: val_loss improved from 0.63477 to 0.63124, saving model to weights.hdf5
# Epoch 42/100
# 35000/35000 [==============================] - 29s 819us/step - loss: 0.6201 - acc: 0.6549 - val_loss: 0.6581 - val_acc: 0.6169
#
# Epoch 00042: val_loss did not improve from 0.63124
# Epoch 43/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6208 - acc: 0.6545 - val_loss: 0.6354 - val_acc: 0.6413
#
# Epoch 00043: val_loss did not improve from 0.63124
# Epoch 44/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6184 - acc: 0.6603 - val_loss: 0.6369 - val_acc: 0.6365
#
# Epoch 00044: val_loss did not improve from 0.63124
# Epoch 45/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6153 - acc: 0.6594 - val_loss: 0.6313 - val_acc: 0.6443
#
# Epoch 00045: val_loss did not improve from 0.63124
# Epoch 46/100
# 35000/35000 [==============================] - 29s 824us/step - loss: 0.6127 - acc: 0.6654 - val_loss: 0.6501 - val_acc: 0.6296
#
# Epoch 00046: val_loss did not improve from 0.63124
# Epoch 47/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6091 - acc: 0.6676 - val_loss: 0.6285 - val_acc: 0.6488
#
# Epoch 00047: val_loss improved from 0.63124 to 0.62845, saving model to weights.hdf5
# Epoch 48/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.6086 - acc: 0.6664 - val_loss: 0.6572 - val_acc: 0.6123
#
# Epoch 00048: val_loss did not improve from 0.62845
# Epoch 49/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.6064 - acc: 0.6695 - val_loss: 0.6502 - val_acc: 0.6275
#
# Epoch 00049: val_loss did not improve from 0.62845
# Epoch 50/100
# 35000/35000 [==============================] - 29s 822us/step - loss: 0.6050 - acc: 0.6719 - val_loss: 0.6367 - val_acc: 0.6349
#
# Epoch 00050: val_loss did not improve from 0.62845
# Epoch 51/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.6028 - acc: 0.6729 - val_loss: 0.6336 - val_acc: 0.6409
#
# Epoch 00051: val_loss did not improve from 0.62845
# Epoch 52/100
# 35000/35000 [==============================] - 29s 824us/step - loss: 0.5996 - acc: 0.6755 - val_loss: 0.6372 - val_acc: 0.6405
#
# Epoch 00052: val_loss did not improve from 0.62845
# Epoch 53/100
# 35000/35000 [==============================] - 29s 818us/step - loss: 0.5989 - acc: 0.6763 - val_loss: 0.6378 - val_acc: 0.6386
#
# Epoch 00053: val_loss did not improve from 0.62845
# Epoch 54/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.5973 - acc: 0.6744 - val_loss: 0.6420 - val_acc: 0.6358
#
# Epoch 00054: val_loss did not improve from 0.62845
# Epoch 55/100
# 35000/35000 [==============================] - 29s 821us/step - loss: 0.5945 - acc: 0.6804 - val_loss: 0.6341 - val_acc: 0.6429
#
# Epoch 00055: val_loss did not improve from 0.62845
# Epoch 56/100
# 35000/35000 [==============================] - 29s 819us/step - loss: 0.5917 - acc: 0.6827 - val_loss: 0.6393 - val_acc: 0.6387
#
# Epoch 00056: val_loss did not improve from 0.62845
# Epoch 57/100
# 35000/35000 [==============================] - 29s 818us/step - loss: 0.5872 - acc: 0.6863 - val_loss: 0.6295 - val_acc: 0.6480
#
# Epoch 00057: val_loss did not improve from 0.62845
# Epoch 58/100
# 35000/35000 [==============================] - 29s 820us/step - loss: 0.5843 - acc: 0.6881 - val_loss: 0.6685 - val_acc: 0.6099
#
# Epoch 00058: val_loss did not improve from 0.62845
# Epoch 59/100
# 35000/35000 [==============================] - 29s 818us/step - loss: 0.5827 - acc: 0.6886 - val_loss: 0.6368 - val_acc: 0.6397
#
# Epoch 00059: val_loss did not improve from 0.62845
# Epoch 60/100
# 35000/35000 [==============================] - 29s 819us/step - loss: 0.5791 - acc: 0.6926 - val_loss: 0.6782 - val_acc: 0.6019
#
# Epoch 00060: val_loss did not improve from 0.62845
# Epoch 61/100
# 35000/35000 [==============================] - 29s 819us/step - loss: 0.5755 - acc: 0.6937 - val_loss: 0.6382 - val_acc: 0.6444
#
# Epoch 00061: val_loss did not improve from 0.62845
# Epoch 62/100
# 35000/35000 [==============================] - 29s 823us/step - loss: 0.5732 - acc: 0.6976 - val_loss: 0.6436 - val_acc: 0.6351
#
# Epoch 00062: val_loss did not improve from 0.62845
# Epoch 63/100
# 35000/35000 [==============================] - 29s 818us/step - loss: 0.5668 - acc: 0.7034 - val_loss: 0.6450 - val_acc: 0.6347
#
# Epoch 00063: val_loss did not improve from 0.62845
# Epoch 64/100
# 35000/35000 [==============================] - 29s 816us/step - loss: 0.5621 - acc: 0.7043 - val_loss: 0.6853 - val_acc: 0.6024
#
# Epoch 00064: val_loss did not improve from 0.62845
# Epoch 65/100
# 35000/35000 [==============================] - 29s 816us/step - loss: 0.5587 - acc: 0.7089 - val_loss: 0.6442 - val_acc: 0.6414
#
# Epoch 00065: val_loss did not improve from 0.62845
# Epoch 66/100
# 35000/35000 [==============================] - 29s 816us/step - loss: 0.5530 - acc: 0.7126 - val_loss: 0.6481 - val_acc: 0.6390
#
# Epoch 00066: val_loss did not improve from 0.62845
# Epoch 67/100
# 35000/35000 [==============================] - 29s 816us/step - loss: 0.5462 - acc: 0.7178 - val_loss: 0.6507 - val_acc: 0.6394
#
# Epoch 00067: val_loss did not improve from 0.62845
# Epoch 00067: early stopping
# Accuracy: 64.04%
